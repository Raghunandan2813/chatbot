# %%
# !pip install arxiv
# Out:
# Collecting arxiv
#   Downloading arxiv-3.0.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting feedparser~=6.0.10 (from arxiv)
#   Downloading feedparser-6.0.12-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: requests<2.34,>=2.32 in C:\Users\raghu\Desktop\Chatbot\.venv\Lib\site-packages (from arxiv) (2.33.1)
# Collecting sgmllib3k (from feedparser~=6.0.10->arxiv)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\raghu\Desktop\Chatbot\.venv\Lib\site-packages (from requests<2.34,>=2.32->arxiv) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\raghu\Desktop\Chatbot\.venv\Lib\site-packages (from requests<2.34,>=2.32->arxiv) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\raghu\Desktop\Chatbot\.venv\Lib\site-packages (from requests<2.34,>=2.32->arxiv) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\raghu\Desktop\Chatbot\.venv\Lib\site-packages (from requests<2.34,>=2.32->arxiv) (2026.2.25)
# Downloading arxiv-3.0.0-py3-none-any.whl (11 kB)
# Downloading feedparser-6.0.12-py3-none-any.whl (81 kB)
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (pyproject.toml): started
#   Building wheel for sgmllib3k (pyproject.toml): finished with status 'done'
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6116 sha256=31920fbbf15fb8c8e1dbbdd1e868913be85d50d25b82f15b3d90ed2bbf6e9dba
#   Stored in directory: c:\users\raghu\appdata\local\pip\cache\wheels\e3\43\83\0f6e317d0698ac38ee6a5b6e214019c167057916a11bad91ab
# Successfully built sgmllib3k
# Installing collected packages: sgmllib3k, feedparser, arxiv
#
#    ------------- -------------------------- 1/3 [feedparser]
#    ------------- -------------------------- 1/3 [feedparser]
#    ------------- -------------------------- 1/3 [feedparser]
#    ------------- -------------------------- 1/3 [feedparser]
#    ------------- -------------------------- 1/3 [feedparser]
#    -------------------------- ------------- 2/3 [arxiv]
#    ---------------------------------------- 3/3 [arxiv]
#
# Successfully installed arxiv-3.0.0 feedparser-6.0.12 sgmllib3k-1.0.0

# %%
from langchain_community.tools import WikipediaQueryRun
from langchain_community.utilities import WikipediaAPIWrapper

# %%
 api_wrapper=WikipediaAPIWrapper(top_k_results=1, doc_content_chars_max=200)
 wiki=WikipediaQueryRun(api_wrapper=api_wrapper)

# %%
wiki.name
# Out:
# 'wikipedia'

# %%
from langchain_community.document_loaders import WebBaseLoader
from langchain_community.vectorstores import FAISS
from langchain_community.embeddings import OllamaEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter

loader=WebBaseLoader("https://docs.langchain.com/langsmith/home")
docs = loader.load()
documents=RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200).split_documents(docs)
vectordb=FAISS.from_documents(documents, OllamaEmbeddings())
retriever=vectordb.as_retriever()
retriever
# Out:
# VectorStoreRetriever(tags=['FAISS', 'OllamaEmbeddings'], vectorstore=<langchain_community.vectorstores.faiss.FAISS object at 0x000001D6EDDB39D0>, search_kwargs={})

# %%
def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

# %%
from langchain_core.runnables import RunnablePassthrough

def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

rag_chain = (
    {
        "context": retriever | format_docs,
        "question": RunnablePassthrough()
    }

)

# %%
tool
# Out:
# WikipediaQueryRun(api_wrapper=WikipediaAPIWrapper(wiki_client=<module 'wikipedia' from 'c:\\Users\\raghu\\Desktop\\Chatbot\\.venv\\Lib\\site-packages\\wikipedia\\__init__.py'>, top_k_results=1, lang='en', load_all_available_meta=False, doc_content_chars_max=200))

# %%
##Arxiv tool

from langchain_community.utilities import ArxivAPIWrapper
from langchain_community.tools import ArxivQueryRun
arxiv_wrapper=ArxivAPIWrapper(top_k_results=1, doc_content_chars_max=100)
arxiv=ArxivQueryRun(api_wrapper=arxiv_wrapper)
arxiv.name
# Out:
# 'arxiv'

# %%
tools=[wiki, arxiv]

# %%
### Agents
from langchain_community.chat_models import ChatOllama

llm = ChatOllama(model="phi3")

response = llm.invoke("What is arXiv:2604.21809 research paper?")
print(response.content)
# Out:
# The arXiv:2604.21809 refers to a preprint uploaded on the arXiv platform, which is an open-access repository for electronic scientific articles in the fields of physics, mathematics, computer science, engineering, and other related areas. The paper titled "Multimodal Transformer Models: State of Research" by Ding et al., was submitted to arXiv on April 13th, 2026 but as this is a hypothetical scenario I cannot provide specific details without access to the full text or abstract at that time.
#
# However, given the title and submission date, we can speculate about its contents based on knowledge available up until early-mid 2023: The paper would likely focus on transformer models' ability to process multiple modalities of data (like images, audio, video), which have shown significant advancements in Natural Language Processing tasks. Researchers often explore multimodal approaches for a better understanding and representation learning as it allows the model not just text but also visual or auditory contexts associated with words/phrases to learn from their interactions leading towards superior performance over traditional models that focus on single modality data only, such as text-only NLP.
#
# In summary: arXiv preprint - Multimodal Transformer Models' State of Research (hypothetically submitted by Ding et al., April 2026) would delve into the latest advancements and applications of transformer models processing multimodal data, likely exploring methodologies for effectively integrating diverse inputs in a unified model framework.
